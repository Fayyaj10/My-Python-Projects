# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       PARTNER_OWNER_ID  DRIVER_ID  DRIVER_MOBILE         MSISDN  \
# 0              1153871    1192174     7338333355  7338333355616
# 1               876119     902610     8970070677  8970070677211
# 2              1323773    1376556     8431996281  8431996281089
# 3               903121     902782     9632694026  9632694026629
# 4              1003038    1032138     9353376181  9353376181987
# ...                ...        ...            ...            ...
# 1136             42603      56493     9141228864  9141228864548
# 1137            543622     560301     9902815794  9902815794270
# 1138            494403     125254     9916463035  9916463035412
# 1139             58491      76915     9632464297  9632464297832
# 1140           1028271     777949     9945513806  9945513806098
#
#       GEO_REGION_ID  WALLET_BALANCE
# 0                 3        -2000.84
# 1                 3          173.80
# 2                 3            0.00
# ...

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")  # or full path to your file
df.head()  # this line shows the data
# Out:
#    PARTNER_OWNER_ID  DRIVER_ID  DRIVER_MOBILE         MSISDN  GEO_REGION_ID  \
# 0           1153871    1192174     7338333355  7338333355616              3
# 1            876119     902610     8970070677  8970070677211              3
# 2           1323773    1376556     8431996281  8431996281089              3
# 3            903121     902782     9632694026  9632694026629              3
# 4           1003038    1032138     9353376181  9353376181987              3
#
#    WALLET_BALANCE
# 0        -2000.84
# 1          173.80
# 2            0.00
# 3        -1162.33
# 4        -1227.95

# %%
# !pip install plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 8.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
import plotly.express as px

# %%
fig = px.scatter(df, x="Date", y="Sales", color="Region", title="Sales by Region Over Time")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig = px.scatter(df, x="Date", y="Sales", color="Region", title="Sales by Region Over Time")
#       2 fig.show()
#
# ...

# %%
fig = px.bar(df, x="Region", y="Sales", color="Region", title="Total Sales by Region")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fig = px.bar(df, x="Region", y="Sales", color="Region", title="Total Sales by Region")
#       2 fig.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/express/_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
# ...

# %%
df.columns
# Out:
# Index(['PARTNER_OWNER_ID', 'DRIVER_ID', 'DRIVER_MOBILE', 'MSISDN',
#        'GEO_REGION_ID', 'WALLET_BALANCE'],
#       dtype='object')
